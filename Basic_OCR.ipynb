# %% [markdown]
# # Basic Character Recognition Using Optical Character Recognition (EasyOCR)

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# %%
img = cv2.imread('tr2.png')
#threshold = 0.25

# %%
reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
text_ = reader.readtext(img)
print(text_)
# Out:
# [([[65, 63], [157, 63], [157, 89], [65, 89]], 'CRoSS', 0.4267763058429255), ([[54, 96], [170, 96], [170, 122], [54, 122]], 'TRAFFIC', 0.9991727804304262), ([[66, 128], [166, 128], [166, 156], [66, 156]], 'AHEAD_', 0.9207685470423896)]

# %%
for t in text_:
    print(t)
    
    bbox, text, score = t
    
    if score > threshold:
        cv2.rectangle(img,bbox[0],bbox[2],(0,0,255),2)
        cv2.putText(img,text,bbox[0],cv2.FONT_HERSHEY_SIMPLEX,0.50,(255,0,0),2)
    
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ([[65, 63], [157, 63], [157, 89], [65, 89]], 'CRoSS', 0.4267763058429255)
# ([[54, 96], [170, 96], [170, 122], [54, 122]], 'TRAFFIC', 0.9991727804304262)
# ([[66, 128], [166, 128], [166, 156], [66, 156]], 'AHEAD_', 0.9207685470423896)
